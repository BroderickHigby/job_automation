# %%
import pandas as pd

# %%
ny = pd.read_csv('new_york_no_space.csv')
table = pd.read_csv('The_Future_of_Employment_Table.csv')

# %%
df = pd.DataFrame.merge(ny, table, on="SOC_CODE")
df
# Out:
#       Area Type   Area                Area Name SOC_CODE  \
# 0            10      1           Capital Region  11-1011
# 1            10      2  Central New York Region  11-1011
# 2            10      3      Finger Lakes Region  11-1011
# 3            10      4     Hudson Valley Region  11-1011
# 4            10      5       Long Island Region  11-1011
# 5            10      6     Mohawk Valley Region  11-1011
# 6            10      7     New York City Region  11-1011
# 7            10      8     North Country Region  11-1011
# 8            10      9     Southern Tier Region  11-1011
# 9            10     10  Western New York Region  11-1011
# 10            1     36           New York State  11-1011
# 11           10      1           Capital Region  11-1021
# 12           10      2  Central New York Region  11-1021
# 13           10      3      Finger Lakes Region  11-1021
# 14           10      4     Hudson Valley Region  11-1021
# ...

# %%
# df.pivot(index='SOC_CODE',columns='Occupation',values='Probability')
# pivot = df.stack(level='SOC_CODE')
pd.DataFrame.to_csv(df, 'pivot_merged.csv')
